# %%
import pandas as pd

# %%
df_appart=pd.read_csv("https://www.data.gouv.fr/fr/datasets/r/87038926-fb31-4959-b2ae-7a24321c599a", sep="|")
# Out:
# /tmp/ipykernel_253/4213222410.py:1: DtypeWarning: Columns (18,23,24,26,28,31,33,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_appart=pd.read_csv("https://www.data.gouv.fr/fr/datasets/r/87038926-fb31-4959-b2ae-7a24321c599a", sep="|")

# %%
df_appart.sample(15)
# Out:
#          Code service sages  Reference document  1 Articles CGI  \
# 340647                  NaN                 NaN             NaN
# 439463                  NaN                 NaN             NaN
# 346491                  NaN                 NaN             NaN
# 926978                  NaN                 NaN             NaN
# 752728                  NaN                 NaN             NaN
# 397702                  NaN                 NaN             NaN
# 1246944                 NaN                 NaN             NaN
# 1003629                 NaN                 NaN             NaN
# 1308719                 NaN                 NaN             NaN
# 1415286                 NaN                 NaN             NaN
# 455311                  NaN                 NaN             NaN
# 1200234                 NaN                 NaN             NaN
# 1347148                 NaN                 NaN             NaN
# 1228189                 NaN                 NaN             NaN
# ...
