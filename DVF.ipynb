# %%
import pandas as pd

# %%
df=pd.read_csv("https://www.data.gouv.fr/fr/datasets/r/817204ac-2202-4b4a-98e7-4184d154d98c", sep="|", dtype={'Code postal':str})
df
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3165: DtypeWarning: Columns (18,23,24,26,28,30,31,33,41) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#          Code service sages  Reference document  1 Articles CGI  \
# 0                       NaN                 NaN             NaN
# 1                       NaN                 NaN             NaN
# 2                       NaN                 NaN             NaN
# 3                       NaN                 NaN             NaN
# 4                       NaN                 NaN             NaN
# ...                     ...                 ...             ...
# 4375218                 NaN                 NaN             NaN
# 4375219                 NaN                 NaN             NaN
# 4375220                 NaN                 NaN             NaN
# ...

# %%
df2=df[['Nature mutation','Valeur fonciere','Code postal','Commune','Code type local','Surface reelle bati','Surface terrain']]
df2
# Out:
#         Nature mutation Valeur fonciere Code postal        Commune  \
# 0                 Vente       185000,00        1370  VAL-REVERMONT
# 1                 Vente       185000,00        1370  VAL-REVERMONT
# 2                 Vente           10,00        1290            BEY
# 3                 Vente       204332,00        1310        BUELLAS
# 4                 Vente       320000,00        1250      MONTAGNAT
# ...                 ...             ...         ...            ...
# 4375218           Vente       383000,00       75004       PARIS 04
# 4375219           Vente       260000,00       75002       PARIS 02
# 4375220           Vente        38000,00       75004       PARIS 04
# 4375221           Vente        38000,00       75004       PARIS 04
# 4375222           Vente       690000,00       75002       PARIS 02
#
#          Code type local  Surface reelle bati  Surface terrain
# 0                    1.0                 97.0           2410.0
# ...

# %%
df2=df2.dropna()
df2
# Out:
#         Nature mutation Valeur fonciere Code postal        Commune  \
# 0                 Vente       185000,00        1370  VAL-REVERMONT
# 1                 Vente       185000,00        1370  VAL-REVERMONT
# 3                 Vente       204332,00        1310        BUELLAS
# 4                 Vente       320000,00        1250      MONTAGNAT
# 5                 Vente       320000,00        1250      MONTAGNAT
# ...                 ...             ...         ...            ...
# 4375192           Vente      2000000,00       75002       PARIS 02
# 4375193           Vente      2000000,00       75002       PARIS 02
# 4375194           Vente      2000000,00       75002       PARIS 02
# 4375195           Vente      2000000,00       75002       PARIS 02
# 4375196           Vente      2000000,00       75002       PARIS 02
#
#          Code type local  Surface reelle bati  Surface terrain
# 0                    1.0                 97.0           2410.0
# ...

# %%
df2=df2[df2["Code postal"].str.startswith('1300')|df2["Code postal"].str.startswith('1301')]
df2.sample(10)
# Out:
#        Nature mutation Valeur fonciere Code postal          Commune  \
# 417444           Vente       430000,00       13012  MARSEILLE 12EME
# 403047           Vente       630000,00       13001    MARSEILLE 1ER
# 406198           Vente      1900000,00       13006   MARSEILLE 6EME
# 419930           Vente      1500000,00       13003   MARSEILLE 3EME
# 416444           Vente       440000,00       13001    MARSEILLE 1ER
# 430787           Vente       448450,00       13011  MARSEILLE 11EME
# 413244           Vente       369550,00       13012  MARSEILLE 12EME
# 417959           Vente       618250,00       13009   MARSEILLE 9EME
# 426285           Vente       295000,00       13011  MARSEILLE 11EME
# 425294           Vente       300000,00       13003   MARSEILLE 3EME
#
#         Code type local  Surface reelle bati  Surface terrain
# 417444              1.0                140.0            288.0
# 403047              2.0                 40.0             56.0
# ...
